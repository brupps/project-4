# %%
# import pandas and load and preview the dataset
import pandas as pd
df = pd.read_csv("Resources/movies_cleaned.csv")
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# create column for the percentage the gross is of the budget
df["percentage"] = ((df["gross"]/df["budget"]) * 100)
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# create categories/bins for the percentage and add to dataframe
import numpy as np

bins = [0, 100, 200, 300]
labels = np.array([1, 2, 3, 4])
df["profit_category"] = labels[np.searchsorted(bins, df["percentage"])-1]

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# create a copy of the dataframe and drop columns that will not be used as features or the target
df_copy = df.copy()

df_copy = df_copy.drop(columns=['name', 'year', 'released', 'director', 'writer', 'star', 'company', 'percentage'])
df_copy.head()
# Out:
#   rating      genre  score      votes         country      budget  \
# 0      R      Drama    8.4   927000.0  United Kingdom  19000000.0
# 1      R  Adventure    5.8    65000.0   United States   4500000.0
# 2     PG     Action    8.7  1200000.0   United States  18000000.0
# 3     PG     Comedy    7.7   221000.0   United States   3500000.0
# 4      R     Comedy    7.3   108000.0   United States   6000000.0
#
#          gross  runtime  profit_category
# 0   46998772.0    146.0                3
# 1   58853106.0    104.0                4
# 2  538375067.0    124.0                4
# 3   83453539.0     88.0                4
# 4   39846344.0     98.0                4

# %%
# use get dummies to encode the non-numerical columns
dummies_df = pd.get_dummies(data=df_copy)

dummies_df.head()
# Out:
#    score      votes      budget        gross  runtime  profit_category  \
# 0    8.4   927000.0  19000000.0   46998772.0    146.0                3
# 1    5.8    65000.0   4500000.0   58853106.0    104.0                4
# 2    8.7  1200000.0  18000000.0  538375067.0    124.0                4
# 3    7.7   221000.0   3500000.0   83453539.0     88.0                4
# 4    7.3   108000.0   6000000.0   39846344.0     98.0                4
#
#    rating_Approved  rating_G  rating_NC-17  rating_Not Rated  ...  \
# 0            False     False         False             False  ...
# 1            False     False         False             False  ...
# 2            False     False         False             False  ...
# 3            False     False         False             False  ...
# 4            False     False         False             False  ...
#
#    country_Spain  country_Sweden  country_Switzerland  country_Taiwan  \
# ...

# %%
# dependencies for scaling and random forest

from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# define X and y for training
X = dummies_df.drop(columns="profit_category")
y = dummies_df["profit_category"]

#split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
# scale the data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#set it up
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)

#fit it
rf_model = rf_model.fit(X_train_scaled, y_train)

#predict
predictions = rf_model.predict(X_test_scaled)

# %%
# calculate accuracy score

accuracy_score(y_test, predictions)
# Out:
# 0.7581120943952803

# %%
# this is a reduction in accuracy- try removing score & votes columns
try2_df = df.copy()

try2_df = try2_df.drop(columns=['name', 'year', 'released', 'score', 'votes', 'director',
                                'writer', 'star', 'company', 'percentage'])

try2_df.head()
# Out:
#   rating      genre         country      budget        gross  runtime  \
# 0      R      Drama  United Kingdom  19000000.0   46998772.0    146.0
# 1      R  Adventure   United States   4500000.0   58853106.0    104.0
# 2     PG     Action   United States  18000000.0  538375067.0    124.0
# 3     PG     Comedy   United States   3500000.0   83453539.0     88.0
# 4      R     Comedy   United States   6000000.0   39846344.0     98.0
#
#    profit_category
# 0                3
# 1                4
# 2                4
# 3                4
# 4                4

# %%
# use get dummies to encode the non-numerical columns
dummies2_df = pd.get_dummies(data=try2_df)

dummies2_df.head()
# Out:
#        budget        gross  runtime  profit_category  rating_Approved  \
# 0  19000000.0   46998772.0    146.0                3            False
# 1   4500000.0   58853106.0    104.0                4            False
# 2  18000000.0  538375067.0    124.0                4            False
# 3   3500000.0   83453539.0     88.0                4            False
# 4   6000000.0   39846344.0     98.0                4            False
#
#    rating_G  rating_NC-17  rating_Not Rated  rating_PG  rating_PG-13  ...  \
# 0     False         False             False      False         False  ...
# 1     False         False             False      False         False  ...
# 2     False         False             False       True         False  ...
# 3     False         False             False       True         False  ...
# 4     False         False             False      False         False  ...
#
#    country_Spain  country_Sweden  country_Switzerland  country_Taiwan  \
# ...

# %%
# define X and y for training
X = dummies2_df.drop(columns="profit_category")
y = dummies2_df["profit_category"]

#split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
# scale the data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#set it up
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)

#fit it
rf_model = rf_model.fit(X_train_scaled, y_train)

#predict
predictions = rf_model.predict(X_test_scaled)

# %%
# calculate accuracy score

accuracy_score(y_test, predictions)
# Out:
# 0.7957227138643068

# %%
# better but still lower than original. try removing country

try3_df = df.copy()

try3_df = try3_df.drop(columns=['name', 'year', 'released', 'score', 'votes', 'director',
                                'writer', 'star', 'country', 'company', 'percentage'])

try3_df.head()
# Out:
#   rating      genre      budget        gross  runtime  profit_category
# 0      R      Drama  19000000.0   46998772.0    146.0                3
# 1      R  Adventure   4500000.0   58853106.0    104.0                4
# 2     PG     Action  18000000.0  538375067.0    124.0                4
# 3     PG     Comedy   3500000.0   83453539.0     88.0                4
# 4      R     Comedy   6000000.0   39846344.0     98.0                4

# %%
# use get dummies to encode the non-numerical columns
dummies3_df = pd.get_dummies(data=try3_df)

dummies3_df.head()
# Out:
#        budget        gross  runtime  profit_category  rating_Approved  \
# 0  19000000.0   46998772.0    146.0                3            False
# 1   4500000.0   58853106.0    104.0                4            False
# 2  18000000.0  538375067.0    124.0                4            False
# 3   3500000.0   83453539.0     88.0                4            False
# 4   6000000.0   39846344.0     98.0                4            False
#
#    rating_G  rating_NC-17  rating_Not Rated  rating_PG  rating_PG-13  ...  \
# 0     False         False             False      False         False  ...
# 1     False         False             False      False         False  ...
# 2     False         False             False       True         False  ...
# 3     False         False             False       True         False  ...
# 4     False         False             False      False         False  ...
#
#    genre_Crime  genre_Drama  genre_Family  genre_Fantasy  genre_Horror  \
# ...

# %%
# define X and y for training
X = dummies3_df.drop(columns="profit_category")
y = dummies3_df["profit_category"]

#split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
# scale the data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#set it up
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)

#fit it
rf_model = rf_model.fit(X_train_scaled, y_train)

#predict
predictions = rf_model.predict(X_test_scaled)

# %%
# calculate accuracy score

accuracy_score(y_test, predictions)
# Out:
# 0.8510324483775811

# %%
# try with no gross!!
no_gross = df.copy()

no_gross = no_gross.drop(columns=['name', 'year', 'released', 'score', 'votes', 'director',
                                'writer', 'star', 'country', 'gross', 'company', 'percentage'])
no_gross.head()
# Out:
#   rating      genre      budget  runtime  profit_category
# 0      R      Drama  19000000.0    146.0                3
# 1      R  Adventure   4500000.0    104.0                4
# 2     PG     Action  18000000.0    124.0                4
# 3     PG     Comedy   3500000.0     88.0                4
# 4      R     Comedy   6000000.0     98.0                4

# %%
# use get dummies to encode the non-numerical columns
dummies4_df = pd.get_dummies(data=no_gross)

dummies4_df.head()
# Out:
#        budget  runtime  profit_category  rating_Approved  rating_G  \
# 0  19000000.0    146.0                3            False     False
# 1   4500000.0    104.0                4            False     False
# 2  18000000.0    124.0                4            False     False
# 3   3500000.0     88.0                4            False     False
# 4   6000000.0     98.0                4            False     False
#
#    rating_NC-17  rating_Not Rated  rating_PG  rating_PG-13  rating_R  ...  \
# 0         False             False      False         False      True  ...
# 1         False             False      False         False      True  ...
# 2         False             False       True         False     False  ...
# 3         False             False       True         False     False  ...
# 4         False             False      False         False      True  ...
#
#    genre_Crime  genre_Drama  genre_Family  genre_Fantasy  genre_Horror  \
# ...

# %%
# define X and y for training
X = dummies4_df.drop(columns="profit_category")
y = dummies4_df["profit_category"]

#split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 1)

# %%
# scale the data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
#set it up
rf_model = RandomForestClassifier(n_estimators=500, random_state=78)

#fit it
rf_model = rf_model.fit(X_train_scaled, y_train)

#predict
predictions = rf_model.predict(X_test_scaled)

# %%
# calculate accuracy score

accuracy_score(y_test, predictions)
# Out:
# 0.3443952802359882

# %%
# back to drawing board- look at original df
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# copy df
new_df = df.copy()

# remove columns we do not want to be features
new_df = new_df.drop(columns = ['name', 'released', 'director', ''])
